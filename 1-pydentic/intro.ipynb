# %% [markdown]
# Pydantic basics:
# pydantic modeles are the foundation of data validation in python they use python type annotation to define the structure and validate data at runtime

# %%
from pydantic import BaseModel

# %%
class Person(BaseModel):
    name:str
    age:int
    city:str

person=Person(name="Revati",age=22,city="Nashik")
print(person)
# Out:
# name='Revati' age=22 city='Nashik'

# %%
type(person)
# Out:
# __main__.Person

# %% [markdown]
# Model with optional field

# %%
from typing import Optional
class Employee(BaseModel):
    id:int
    name:str
    department:str
    salary: Optional[float]=None
    is_active: Optional[bool]=True

# %%
emp1 = Employee(id=1, name="Vrushali",department="It")
print(emp1)
# Out:
# id=1 name='Vrushali' department='It' salary=None is_active=True

# %%
emp2 = Employee(id=1, name="Vrushali",department="It",salary=600000,is_active=False)
print(emp2)
# Out:
# id=1 name='Vrushali' department='It' salary=600000.0 is_active=False

# %% [markdown]
# Optional[type]: Indicate the field can be none
#
# Default value:(=None = True): Makes the field optional
# required data must be provided
# pydentic validation types even for optional field when values are provided

# %%
from pydantic import BaseModel
from typing import List

class Classroom(BaseModel):
    room_number: str
    students: List[str]
    capacity: int

# %%
classroom = Classroom(
    room_number = "A102",
    students = ["Revati","vrushali","vinod"],
    capacity = 30

)
print(classroom)
# Out:
# room_number='A102' students=['Revati', 'vrushali', 'vinod'] capacity=30

# %%
classroom = Classroom(
    room_number = "A102",
    students = ("Revati","vrushali","vinod"),
    capacity = 30

)
print(classroom)
# Out:
# room_number='A102' students=['Revati', 'vrushali', 'vinod'] capacity=30

# %%
try:
    invalid_val=Classroom(room_number="Y76",students=["surekha",123],capacity=30)
except ValueError as e:
    print(e)
# Out:
# 1 validation error for Classroom
# students.1
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type

# %% [markdown]
# Model with Nested models
#
# Create complex structure with nested models

# %%
from pydantic import BaseModel

class Address(BaseModel):
    street: str
    city: str
    zip_code: str

class Customer(BaseModel):
    customer_id: int
    name: str
    address: Address
    

customer = Customer(
    customer_id=1,
    name="Sweety",
    address={"street": "123 main st", "city": "Nashik", "zip_code":"02738"}


)
print(customer)
# Out:
# customer_id=1 name='Sweety' address=Address(street='123 main st', city='Nashik', zip_code='02738')

# %%
from pydantic import BaseModel

class Address(BaseModel):
    street: str
    city: str
    zip_code: int

class Customer(BaseModel):
    customer_id: int
    name: str
    address: Address
    

customer = Customer(
    customer_id=1,
    name="Sweety",
    address={"street": "123 main st", "city": "Nashik", "zip_code":"02738"}


)
print(customer)
# Out:
# customer_id=1 name='Sweety' address=Address(street='123 main st', city='Nashik', zip_code=2738)

# %% [markdown]
# #### Pydantic fields:customization and constarints
#
# The field function in pydantic enhance model fields beyond basic type hints by allowing you to specify validation rules,default values,aliases and more here's example

# %%
from pydantic import BaseModel,Field
class Item(BaseModel):
    name:str=Field(min_length=2,max_length=50)
    price:float= Field(gt=0, le=1000)
    quantity:int=Field(ge=0)
    
item = Item(name="Book", price=10, quantity=10)
print(item)
# Out:
# name='Book' price=10.0 quantity=10

# %%
from pydantic import BaseModel, FieldSerializationInfo
class User(BaseModel):
    username: str = Field(..., description="Unique username for the user")
    age: int = Field(default=18, description="user age default to 18")
    email: str = Field(default_factory=lambda: "user@example.com", description="default email address")

user1 = User(username="revati")
print(user1)

user2 = User(username="vrushali", age=26, email = "revatip290@gmail.com")
print(user2)
# Out:
# username='revati' age=18 email='user@example.com'
# username='vrushali' age=26 email='revatip290@gmail.com'
